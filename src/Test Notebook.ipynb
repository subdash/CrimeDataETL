# %% [markdown]
# ## Demonstration of service

# %%
from crime_data import CrimeDataService, DataSet

all_race_data = CrimeDataService.get_all_data(DataSet.RACE)
all_age_data = CrimeDataService.get_all_data(DataSet.AGE)

# %%
all_race_data
# Out:
#                                 Offenses   All races      White      Black  \
# 0                           All offenses  10287860.0  7605750.0  2500420.0
# 1   Murder and nonnegligent manslaughter     20040.0    10380.0     9360.0
# 2                          Forcible rape     31380.0    16140.0    14760.0
# 3                                Robbery    146270.0    60410.0    84140.0
# 4                     Aggravated assault    277470.0   174800.0    98150.0
# ..                                   ...         ...        ...        ...
# 26   All other offenses (except traffic)   3318450.0  2319930.0   874280.0
# 27                  Curfew and loitering     14650.0     9640.0     4380.0
# 28                   Violent Crime Index         NaN        NaN        NaN
# 29                  Property Crime Index   1074370.0   717390.0   320270.0
# 30                       Violent crimes*    470890.0   276310.0   172980.0
#
#     American Indian    Asian  Year  % White Pop.  % White Crimes  \
# 0          122640.0  59050.0  1980          83.0           73.93
# 1             160.0    150.0  1980          83.0           51.80
# 2             280.0    200.0  1980          83.0           51.43
# 3             780.0    950.0  1980          83.0           41.30
# 4            3140.0   1380.0  1980          83.0           63.00
# ..              ...      ...   ...           ...             ...
# 26          81790.0  42460.0  2019          72.4           69.91
# 27            380.0    260.0  2019          72.4           65.80
# 28              NaN      NaN  2019          72.4             NaN
# 29          20450.0  16260.0  2019          72.4           66.77
# 30          11110.0  10480.0  2019          72.4           58.68
#
#     % Black Pop.  % Black Crimes  % American Indian Pop.  \
# 0           11.7           24.30                     0.8
# 1           11.7           46.71                     0.8
# 2           11.7           47.04                     0.8
# 3           11.7           57.52                     0.8
# 4           11.7           35.37                     0.8
# ..           ...             ...                     ...
# 26          12.6           26.35                     0.9
# 27          12.6           29.90                     0.9
# 28          12.6             NaN                     0.9
# 29          12.6           29.81                     0.9
# 30          12.6           36.73                     0.9
#
#     % American Indian Crimes  % Asian Pop.  % Asian Crimes
# 0                       1.19           1.5            0.57
# 1                       0.80           1.5            0.75
# 2                       0.89           1.5            0.64
# 3                       0.53           1.5            0.65
# 4                       1.13           1.5            0.50
# ..                       ...           ...             ...
# 26                      2.46           6.2            1.28
# 27                      2.59           6.2            1.77
# 28                       NaN           6.2             NaN
# 29                      1.90           6.2            1.51
# 30                      2.36           6.2            2.23
#
# [1240 rows x 15 columns]

# %%
all_age_data
# Out:
#                                 Offenses    All ages    0 to 17  18 & older  \
# 0                           All offenses  10287860.0  2012630.0   8275230.0
# 1   Murder and nonnegligent manslaughter     20040.0     1800.0     18240.0
# 2                          Forcible rape     31380.0     4600.0     26780.0
# 3                                Robbery    146270.0    44760.0    101510.0
# 4                     Aggravated assault    277470.0    40410.0    237060.0
# ..                                   ...         ...        ...         ...
# 26   All other offenses (except traffic)   3318450.0   144160.0   3174300.0
# 27                  Curfew and loitering     14650.0    14650.0         0.0
# 28                   Violent Crime Index         NaN        NaN         NaN
# 29                  Property Crime Index   1074370.0   119790.0    954570.0
# 30                       Violent crimes*    470890.0    44010.0    426870.0
#
#      10 to 17   0 to 14   15 to 17   18 to 20   21 to 24  25 & older  Year
# 0   1959280.0  576120.0  1436510.0  1826470.0  1850280.0   4598470.0  1980
# 1      1790.0     210.0     1590.0     3100.0     3970.0     11170.0  1980
# 2      4570.0    1060.0     3540.0     5350.0     6930.0     14500.0  1980
# 3     44440.0   10670.0    34100.0    33680.0    28810.0     39020.0  1980
# 4     39700.0   10460.0    29950.0    41270.0    53030.0    142770.0  1980
# ..        ...       ...        ...        ...        ...         ...   ...
# 26   143410.0   42580.0   101570.0   201060.0   367700.0   2605540.0  2019
# 27    14630.0    4930.0     9730.0        0.0        0.0         0.0  2019
# 28        NaN       NaN        NaN        NaN        NaN         NaN  2019
# 29   119280.0   36410.0    83380.0   100450.0   116780.0    737340.0  2019
# 30    43810.0   13130.0    30880.0    41250.0    58850.0    326770.0  2019
#
# [1240 rows x 11 columns]
